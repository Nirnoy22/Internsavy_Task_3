# %% [markdown]
# ## ```Customer Segmentation Analysis```

# %% [markdown]
# #### Problem Statement
# **````Customer Segmentation Analysiswith Python````**

# %% [markdown]
# #### The Dataset and its details.

# %%
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

customers = pd.read_csv(r'C:\Users\ASUS\OneDrive\Desktop\Nirnoy\Placement\Internshevy\Mall_Customers.csv')
customers
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
customers.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
print('Shape of the data:')
customers.shape
# Out:
# Shape of the data:
# (200, 5)

# %%
print('Missing values in columns:')
customers.isnull().sum()
# Out:
# Missing values in columns:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# From the above we can see that there is no  null values.

# %% [markdown]
# #### Summary Statistics about the dataset.

# %%
cd=customers.describe()
cd
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# #### Gender wise distribution

# %%
sns.countplot(x='Gender', data=customers)
plt.title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %% [markdown]
# #### Create a histogram of ages to see the distributions

# %%
customers.hist('Age', bins=105)
plt.title('Distribution of Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
cd["Age"][1]
# Out:
# 38.85

# %% [markdown]
# From the above Histogram we can see that ages are mostly between 30 and 40.The above **```cd["Age"][1]```** result makes sense. The average age was 38.85,which is quite similar with our histogram plot. There are less older customers, so this distribution is right-skewed because of its longer right tail. This could be because of the appeal of malls and the type of demographic that tends to shop there.

# %%
plt.hist('Age', data=customers[customers['Gender'] == 'Male'], alpha=0.5, label='Male')
plt.hist('Age', data=customers[customers['Gender'] == 'Female'], alpha=0.5, label='Female');
plt.title('Distribution of Age by Gender')
plt.xlabel('Age')
plt.legend()

# %% [markdown]
# We can see the spike around the age of 30–35 for the women.Also,there is a significant amount of senior men in the 65–70 year old.

# %% [markdown]
# #### The Distribution of Income

# %%
customers.hist('Annual Income (k$)')
plt.title('Annual Income Distribution in Thousands of Dollars')
plt.xlabel('Thousands of Dollars')
# Out:
# Text(0.5, 0, 'Thousands of Dollars')

# %% [markdown]
# Much of the incomes lie between the 60 and 85,000 dollar buckets.

# %% [markdown]
# #### Histogram of income by gender.

# %%
plt.hist('Annual Income (k$)', data=customers[customers['Gender'] == 'Male'], alpha=0.5, label='Male');
plt.hist('Annual Income (k$)', data=customers[customers['Gender'] == 'Female'], alpha=0.5, label='Female');
plt.title('Distribution of Income by Gender');
plt.xlabel('Income (Thousands of Dollars)');
plt.legend();

# %% [markdown]
# The women in this data set make less money than the men.

# %% [markdown]
# #### Here we are looking about average spending by gender.

# %%
# Create data sets by gender to save time in the future since gender seems to significantly impact other variables
male_customers = customers[customers['Gender'] == 'Male']
female_customers = customers[customers['Gender'] == 'Female']

# Print the average spending score for men and women
print(male_customers['Spending Score (1-100)'].mean())
print(female_customers['Spending Score (1-100)'].mean())
# Out:
# 48.51136363636363
# 51.526785714285715

# %%
sns.scatterplot('Age', 'Annual Income (k$)', hue='Gender', data=customers)
plt.title('Age to Income, Colored by Gender')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age to Income, Colored by Gender')

# %% [markdown]
# There is no clear correlation.

# %%
sns.heatmap(customers.corr(), annot=True)
plt.title('Correlation Heatmap - By Gender')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - By Gender')

# %%
sns.scatterplot('Age', 'Spending Score (1-100)', hue='Gender', data=customers)
plt.title('Age to Spending Score, Colored by Gender')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age to Spending Score, Colored by Gender')

# %%
sns.heatmap(male_customers.corr(), annot=True)
plt.title('Correlation Heatmap - Male')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - Male')

# %% [markdown]
# From the above table we can conclude that there is a negetive correlation for the Males.

# %%
sns.heatmap(female_customers.corr(), annot=True)
plt.title('Correlation Heatmap - Female')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - Female')

# %% [markdown]
# From the above table we can conclude that correlation bwteen most of the variables for the Female is positive.

# %%
sns.lmplot('Age', 'Spending Score (1-100)', data=female_customers)
plt.title('Age to Spending Score, Female Only')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age to Spending Score, Female Only')

# %%
sns.scatterplot('Annual Income (k$)', 'Spending Score (1-100)', hue='Gender', data=customers)
plt.title('Annual Income to Spending Score, Colored by Gender')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Annual Income to Spending Score, Colored by Gender')

# %% [markdown]
# As a summary we can say that :
#
# - Low income, low spending score<br>
# - Low income, high spending score<br>
# - Mid income, medium spending score<br>
# - High income, low spending score<br>
# - High income, high spending score<br>
